# %% [markdown]
# Cell 1 – Setup

# %%
# 03_taxonomy_mapping.ipynb

import sys
from pathlib import Path

import numpy as np
import pandas as pd

PROJECT_ROOT = Path("..").resolve()
if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

from src.config import load_config
from src.data.loader import load_jobs
from src.taxonomy.mapping import load_onet, build_onet_embeddings, map_clusters_to_soc
from src.clustering.clustering import kmeans_clusters, hdbscan_clusters

cfg = load_config()

EMB_PATH = PROJECT_ROOT / "results" / "embeddings" / "embeddings_desc_clean_len50.npy"
LABELS_PATH = PROJECT_ROOT / "results" / "clusters" / "kmeans_labels.npy"

EMB_PATH, LABELS_PATH
# Out:
# (WindowsPath('C:/Users/hisuk/labor-market-nlp-prototype/results/embeddings/embeddings_desc_clean_len50.npy'),
#  WindowsPath('C:/Users/hisuk/labor-market-nlp-prototype/results/clusters/kmeans_labels.npy'))

# %% [markdown]
# Cell 2 – Load embeddings, labels, and jobs

# %%
embeddings = np.load(EMB_PATH)
labels = np.load(LABELS_PATH)
jobs = load_jobs()

# Load embeddings + labels
embeddings = np.load(EMB_PATH)
labels = np.load(LABELS_PATH)

print("jobs:", jobs.shape)
print("embeddings:", embeddings.shape)
print("labels:", labels.shape)
# Out:
# jobs: (24164, 15)
# embeddings: (24001, 384)
# labels: (24001,)

# %% [markdown]
# Cell 3 – Compute cluster centers

# %%
# ignore negative labels
valid_mask = labels >= 0
X = embeddings[valid_mask]
y = labels[valid_mask]

n_clusters = len(np.unique(y))
print("Number of clusters:", n_clusters)

cluster_centers = np.zeros((n_clusters, embeddings.shape[1]), dtype=np.float32)
for c in range(n_clusters):
    cluster_centers[c] = X[y == c].mean(axis=0)

cluster_centers.shape
# Out:
# Number of clusters: 100
# (100, 384)

# %% [markdown]
# Cell 4 – Load O*NET and build its embeddings

# %%
onet_df = load_onet()
print("O*NET shape:", onet_df.shape)
onet_df.head()
onet_df["Title"].unique()
# Out:
# O*NET shape: (1016, 3)
# array(['Chief Executives', 'Chief Sustainability Officers',
#        'General and Operations Managers', ..., 'Infantry',
#        'Special Forces',
#        'Military Enlisted Tactical Operations and Air/Weapons Specialists and Crew Members, All Other'],
#       shape=(1016,), dtype=object)

# %%
onet_emb = build_onet_embeddings(onet_df)
onet_emb.shape
# Out:
# Batches: 100%|██████████| 16/16 [00:10<00:00,  1.51it/s]
# (1016, 384)

# %% [markdown]
# Cell 5 – Map clusters to SOC codes

# %%
mapping_df = map_clusters_to_soc(
    cluster_centers=cluster_centers,
    onet_df=onet_df,
    onet_emb=onet_emb,
)

mapping_df.head()
# Out:
#    cluster_id                                        soc_matches
# 0           0  [(39-5094.00, 0.5522235035896301), (51-9082.00...
# 1           1  [(47-5013.00, 0.4926125407218933), (49-3091.00...
# 2           2  [(19-3033.00, 0.6344330906867981), (21-1014.00...
# 3           3  [(43-4141.00, 0.5950422286987305), (43-3031.00...
# 4           4  [(11-9141.00, 0.6407411694526672), (41-9021.00...

# %% [markdown]
# Cell 6 – Expand mapping for readability

# %%
rows = []
for _, row in mapping_df.iterrows():
    cid = row["cluster_id"]
    matches = row["soc_matches"]
    if not matches:
        rows.append({"cluster_id": cid, "soc_code": None, "similarity": None})
    else:
        for code, score in matches:
            rows.append({"cluster_id": cid, "soc_code": code, "similarity": score})

mapping_long = pd.DataFrame(rows)
mapping_long.head()
# Out:
#    cluster_id    soc_code  similarity
# 0           0  39-5094.00    0.552224
# 1           0  51-9082.00    0.491284
# 2           0  29-2055.00    0.459426
# 3           1  47-5013.00    0.492613
# 4           1  49-3091.00    0.489898

# %% [markdown]
# Cell 7 – Join back to cluster examples

# %%
in_path = PROJECT_ROOT / "data" / "jobs_with_clusters.parquet"
jobs_with_labels = pd.read_parquet(in_path)

# %%
# pick one cluster and see its mapped SOC codes + example jobs
cluster_id = 0  # choose any id
cluster_mapping = mapping_long[mapping_long["cluster_id"] == cluster_id]
cluster_mapping
# Out:
#    cluster_id    soc_code  similarity
# 0           0  39-5094.00    0.552224
# 1           0  51-9082.00    0.491284
# 2           0  29-2055.00    0.459426

# %%
jobs_with_labels[jobs_with_labels["cluster"] == cluster_id][
    [cfg["jobs"]["id_column"], "speciality", "name", cfg["jobs"]["text_column"]]
].head(5)
# Out:
#       company_id             speciality                          name  \
# 823         9060      Airway Management               Laerdal Medical
# 877       165340  Regenerative Medicine                 Organogenesis
# 1438        9561               Robotics                     Intuitive
# 1624       11073              audiology               Starkey Hearing
# 1737    58360388                   None  Sandstone Medical Solutions
#
#                                             description
# 823   Laerdal Medical is a world leader in healthcar...
# 877   Organogenesis™ is a leading regenerative medic...
# 1438  Intuitive (Nasdaq: ISRG), headquartered in Sun...
# 1624  Starkey is a privately held, global hearing te...
# 1737  Sandstone Medical Solutions is a professional ...

# %%
from src.evaluation.metrics import internal_cluster_metrics, mapping_metrics

# --- 1) internal cluster quality ---
internal = internal_cluster_metrics(
    embeddings=embeddings,
    labels=labels,
    metric="cosine"  # recommended for sentence embeddings
)

# --- 2) taxonomy mapping quality ---
map_eval = mapping_metrics(
    mapping_df=mapping_df,             # must have: cluster_id, soc_matches
    labels=labels,
    similarity_threshold=0.4
)

print("Internal metrics:", internal)
print("Mapping metrics:", map_eval)
# Out:
# Internal metrics: {'silhouette': 0.03062870353460312, 'davies_bouldin': 4.476163984919504, 'n_clusters': 100}
# Mapping metrics: {'n_clusters': 100, 'noise_rate': 0.0, 'coverage': 0.97, 'avg_top1_similarity': 0.5425968219324485, 'avg_top1_margin': 0.034263985636441605}

# %%
rows = []
for _, row in mapping_df.iterrows():
    cid = row["cluster_id"]
    matches = row["soc_matches"]
    if not matches:
        rows.append({"cluster_id": cid, "soc_code": None, "similarity": None})
    else:
        for code, score in matches:
            rows.append({"cluster_id": cid, "soc_code": code, "similarity": score})

mapping_long = pd.DataFrame(rows)
mapping_long.head()
# Out:
#    cluster_id    soc_code  similarity
# 0           0  39-5094.00    0.552224
# 1           0  51-9082.00    0.491284
# 2           0  29-2055.00    0.459426
# 3           1  47-5013.00    0.492613
# 4           1  49-3091.00    0.489898

# %% [markdown]
# Cell 9 – Save Mapping Results

# %%
jobs_used = jobs.iloc[:len(labels)].copy()   # 24001 rows
jobs_used["cluster_id"] = labels

jobs_used.head()

out_path = PROJECT_ROOT / "results" / "reports" / "jobs_with_clusters.csv"
jobs_used.to_csv(out_path, index=False)
print("Saved to:", out_path)
# Out:
# Saved to: C:\Users\hisuk\labor-market-nlp-prototype\results\reports\jobs_with_clusters.csv

# %%
sample_100 = jobs_used.sample(n=100, random_state=42)

sample_100[
    ["cluster_id", "speciality", "name", text_col]
].head(20)
# Out:
#        cluster_id                  speciality  \
# 16031          65                  Consulting
# 21639          12               Cybersecurity
# 7163           10            Eating Disorders
# 16954          37                  Recruiting
# 2518           42          career preparation
# 22862          24       Investment Management
# 18524          99  robotic process automation
# 23213          42                        None
# 18039          26                        None
# 16579          90      Government Contracting
# 1056           77             cystic fibrosis
# 6682           96      DSA modular classrooms
# 10755          45                        None
# 8233           15                       Music
# 19755          66            public relations
# 17760          21        Consumer Electronics
# 14800          31              Premium Coffee
# 1510           16        Engineering & Design
# 15757          66                        None
# 16354          83                        None
#
#                                     name  \
# 16031                             TIMBER
# 21639                      DOIT Security
# 7163              Walden Behavioral Care
# 16954                       AUX Partners
# 2518      Metropolitan Community College
# 22862             Evolve Talent Partners
# 18524                   Ashling Partners
# 23213                           accelant
# 18039                         CAIRE Inc.
# 16579                              RAZOR
# 1056              Vertex Pharmaceuticals
# 6682                    Enviroplex, Inc.
# 10755             Community Living, Inc.
# 8233            Marion Community Schools
# 19755                   The Branded Firm
# 17760                            EcoFlow
# 14800         Black Rifle Coffee Company
# 1510                              Belcan
# 15757  Continental Dairy Facilities, LLC
# 16354                     BWise Trailers
#
#                                              description
# 16031  We Listen. We Act. We Succeed. \n\nTIMBER IT C...
# 21639  OUR STORY\n\nSafety Made Simple\n\nOur Beginni...
# 7163   Walden Behavioral Care's mission is to offer s...
# 16954  Recruiting the Future\n\nAUX is a Full-Scale R...
# 2518   Metropolitan Community College provides educat...
# 22862  The new workforce is anything but traditional…...
# 18524  Ashling Partners is a professional services & ...
# 23213  We accelerate growth for our Customers – top l...
# 18039  CAIRE Inc. leverages its rich legacy in oxygen...
# 16579  RAZOR is a women-owned small business (WOSB) s...
# 1056   Vertex is a global biotechnology company that ...
# 6682   At Enviroplex, a division of McGrath RentCorp,...
# 10755  Community Living Inc. provides life-enriching ...
# 8233   Marion Community Schools is a public school sy...
# 19755  The Branded Firm is a full-service boutique ma...
# 17760  EcoFlow is a leading eco-friendly energy solut...
# 14800  America's Coffee Company. Veteran founded. BRC...
# 1510   Belcan is a global supplier of engineering, ma...
# 15757  Continental Dairy Facilities is a dairy proces...
# 16354  BWISE Trailers manufactures as many of their p...

# %%
# 1) onet_df 컬럼명 표준화
onet_std = onet_df.rename(columns={
    "O*NET-SOC Code": "soc_code",
    "Title": "title",
    "Description": "onet_description",
    "SOC Code": "soc_code",
    "SOC_CODE": "soc_code",
    "title": "title",
    "description": "onet_description",
}).copy()

# 혹시 soc_code가 숫자로 들어있으면 문자열로 통일
onet_std["soc_code"] = onet_std["soc_code"].astype(str)

# 2) mapping_long도 soc_code로 만들어줬으니 그대로 merge
mapping_long = mapping_long.merge(
    onet_std[["soc_code", "title", "onet_description"]],
    on="soc_code",
    how="left"
)


mapping_long.head()
# Out:
#    cluster_id    soc_code  similarity                                title  \
# 0           0  39-5094.00    0.552224                 Skincare Specialists
# 1           0  51-9082.00    0.491284        Medical Appliance Technicians
# 2           0  29-2055.00    0.459426               Surgical Technologists
# 3           1  47-5013.00    0.492613  Service Unit Operators, Oil and Gas
# 4           1  49-3091.00    0.489898                    Bicycle Repairers
#
#                                     onet_description
# 0  Provide skincare treatments to face and body t...
# 1  Construct, maintain, or repair medical support...
# 2  Assist in operations, under the supervision of...
# 3  Operate equipment to increase oil flow from pr...
# 4                       Repair and service bicycles.

# %%
top1_soc = (
    mapping_long
    .sort_values(["cluster_id", "similarity"], ascending=[True, False])
    .groupby("cluster_id")
    .head(1)
)

top1_soc.shape

out_path = PROJECT_ROOT / "results" / "reports" / "top1_soc.csv"
top1_soc.to_csv(out_path, index=False)
print("Saved to:", out_path)
# Out:
# Saved to: C:\Users\hisuk\labor-market-nlp-prototype\results\reports\top1_soc.csv

# %%
# 1) jobs 쪽 cluster 컬럼 통일
if "cluster" in jobs_with_labels.columns:
    jobs_with_labels = jobs_with_labels.rename(columns={"cluster": "cluster_id"})

# 2) top1_soc 쪽도 cluster_id 맞추기 (이미 cluster_id면 그대로)
if "cluster" in top1_soc.columns:
    top1_soc = top1_soc.rename(columns={"cluster": "cluster_id"})

# 3) merge
sample_jobs = jobs_with_labels.sample(n=100, random_state=42)
explore_100 = sample_jobs.merge(top1_soc, on="cluster_id", how="left")

explore_100.head()
# Out:
#    company_id                                               name  \
# 0    10822209                         SageSpring Wealth Partners
# 1    78850703  Doctors Without Borders/Médecins Sans Frontièr...
# 2      310015                                             Rangam
# 3    15161148  Illinois Department of Innovation & Technology...
# 4       21708                               Sun Country Airlines
#
#                                          description  company_size      state  \
# 0  SageSpring Wealth Partners is a firm of more t...           2.0  Tennessee
# 1  Doctors Without Borders/Médecins Sans Frontièr...           2.0         NY
# 2  Rangam is a global, innovative, total talent m...           4.0         NJ
# 3  Vision\nReimagine Illinois government through ...           5.0   Illinois
# 4  Sun Country Airlines (SY and NASDAQ: SNCY) is ...           5.0  Minnesota
#
#   country         city    zip_code                 address  \
# 0      US     Franklin       37067  801 Crescent Centre Dr
# 1      US     New York       10006        40 Rector Street
# 2      US     Somerset        8873     270 Davidson Avenue
# 3      US  Springfield       62702      120 W Jefferson St
# 4      US  Minneapolis  55450-1131         2005 Cargo Road
#
#                                                  url  \
# 0        https://www.linkedin.com/company/sagespring
# 1           https://www.linkedin.com/company/msf-usa
# 2        https://www.linkedin.com/company/rangam-inc
# 3      https://www.linkedin.com/company/illinoisdoit
# 4  https://www.linkedin.com/company/sun-country-a...
#
#                         industry  \
# 0             Financial Services
# 1       Non-profit Organizations
# 2        Staffing and Recruiting
# 3  Computer and Network Security
# 4          Airlines and Aviation
#
#                                           speciality  employee_count  \
# 0                                 financial planning             135
# 1                                               None             249
# 2  Staff augmentation services for IT & Non-IT ca...             532
# 3                                Mobile Applications             370
# 4                                    Vacation Travel            1508
#
#    follower_count  time_recorded  cluster_id    soc_code  similarity  \
# 0            2233     1712432278          65  13-2052.00    0.669340
# 1           22446     1712384618          12  29-2099.08    0.595115
# 2          129105     1712348264          10  27-2012.04    0.549911
# 3            6022     1713208435          37  15-1241.01    0.565313
# 4           33359     1713563800          42  17-3021.00    0.580903
#
#                                                title  \
# 0                        Personal Financial Advisors
# 1                            Patient Representatives
# 2                                   Talent Directors
# 3         Telecommunications Engineering Specialists
# 4  Aerospace Engineering and Operations Technolog...
#
#                                     onet_description
# 0  Advise clients on financial plans using knowle...
# 1  Assist patients in obtaining services, underst...
# 2  Audition and interview performers to select mo...
# 3  Design or configure wired, wireless, and satel...
# 4  Operate, install, adjust, and maintain integra...

# %%
explore_100 = explore_100[
    ["cluster_id", "speciality", "description", "soc_code", "similarity", "title", "onet_description"]
].rename(columns={
    "description": "job_description"
})

explore_100.head()
# Out:
#    cluster_id                                         speciality  \
# 0          65                                 financial planning
# 1          12                                               None
# 2          10  Staff augmentation services for IT & Non-IT ca...
# 3          37                                Mobile Applications
# 4          42                                    Vacation Travel
#
#                                      job_description    soc_code  similarity  \
# 0  SageSpring Wealth Partners is a firm of more t...  13-2052.00    0.669340
# 1  Doctors Without Borders/Médecins Sans Frontièr...  29-2099.08    0.595115
# 2  Rangam is a global, innovative, total talent m...  27-2012.04    0.549911
# 3  Vision\nReimagine Illinois government through ...  15-1241.01    0.565313
# 4  Sun Country Airlines (SY and NASDAQ: SNCY) is ...  17-3021.00    0.580903
#
#                                                title  \
# 0                        Personal Financial Advisors
# 1                            Patient Representatives
# 2                                   Talent Directors
# 3         Telecommunications Engineering Specialists
# 4  Aerospace Engineering and Operations Technolog...
#
#                                     onet_description
# 0  Advise clients on financial plans using knowle...
# 1  Assist patients in obtaining services, underst...
# 2  Audition and interview performers to select mo...
# 3  Design or configure wired, wireless, and satel...
# 4  Operate, install, adjust, and maintain integra...

# %%
out_path = PROJECT_ROOT / "results" / "reports" / "explore_100_jobs_with_onet.csv"
explore_100.to_csv(out_path, index=False)
print("Saved to:", out_path)
# Out:
# Saved to: C:\Users\hisuk\labor-market-nlp-prototype\results\reports\explore_100_jobs_with_onet.csv

# %%
# top1 per cluster
top1_soc = (
    mapping_long
    .sort_values(["cluster_id", "similarity"], ascending=[True, False])
    .dropna(subset=["cluster_id"])                     # 혹시 모를 결측 방지
    .groupby("cluster_id", as_index=False)
    .head(1)
    .reset_index(drop=True)
)

# sanity check: 클러스터 개수 확인
n_clusters = mapping_long["cluster_id"].nunique()
print("clusters in mapping_long:", n_clusters)
print("rows in top1_soc:", len(top1_soc))

# 저장
top1_soc.to_csv(PROJECT_ROOT / "results" / "reports"/"cluster_top1_soc.csv", index=False)
# Out:
# clusters in mapping_long: 100
# rows in top1_soc: 100

# %%
# jobs 데이터프레임 이름은 너 노트북에 맞춰서 선택
jobs_df = jobs_with_labels.copy()   # 또는 jobs_with_labels

# columns 통일
if "cluster" in jobs_df.columns and "cluster_id" not in jobs_df.columns:
    jobs_df = jobs_df.rename(columns={"cluster": "cluster_id"})

# top1_soc도 cluster_id 통일
if "cluster" in top1_soc.columns and "cluster_id" not in top1_soc.columns:
    top1_soc = top1_soc.rename(columns={"cluster": "cluster_id"})

# join (모든 job row 유지)
jobs_labeled = jobs_df.merge(
    top1_soc[["cluster_id", "soc_code", "title", "similarity"]],
    on="cluster_id",
    how="left"
)

# 저장 (parquet 추천: 빠르고 용량 작음)
jobs_labeled.to_parquet(PROJECT_ROOT/"data/clustered_jobs_labeled.parquet", index=False)

# 확인
jobs_labeled[["cluster_id","soc_code","title","similarity"]].head()
# Out:
#    cluster_id    soc_code                                              title  \
# 0          16  15-1221.00       Computer and Information Research Scientists
# 1          14  29-9021.00  Health Information Technologists and Medical R...
# 2          73  15-1243.01                       Data Warehousing Specialists
# 3          46  15-1243.01                       Data Warehousing Specialists
# 4          16  15-1221.00       Computer and Information Research Scientists
#
#    similarity
# 0    0.437538
# 1    0.654816
# 2    0.431172
# 3    0.508563
# 4    0.437538

# %%
import pandas as pd

SAMPLES_PER_CLUSTER = 5

# job 텍스트 컬럼명은 네 config 기준으로
TEXT_COL = "description"  # 필요하면 'text' 등으로 바꾸기

sample_rows = (
    jobs_labeled
    .dropna(subset=["cluster_id"])
    .groupby("cluster_id", group_keys=False)
    .apply(lambda g: g.sample(n=min(SAMPLES_PER_CLUSTER, len(g)), random_state=42))
    .reset_index(drop=True)
)

# 검증용 컬럼 추가
sample_rows["human_judgement"] = ""   # ok / no / uncertain
sample_rows["notes"] = ""

# 검증에 필요한 최소 컬럼만 추려서 저장
cols = [
    "cluster_id", "soc_code", "title", "similarity",
    TEXT_COL
]
keep = [c for c in cols if c in sample_rows.columns] + ["human_judgement", "notes"]

sample_rows[keep].to_csv(PROJECT_ROOT / "results" / "reports" / "cluster_validation_sample.csv", index=False)
sample_rows[keep].head()
# Out:
# C:\Users\hisuk\AppData\Local\Temp\ipykernel_16088\478806474.py:12: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   .apply(lambda g: g.sample(n=min(SAMPLES_PER_CLUSTER, len(g)), random_state=42))
#    cluster_id    soc_code                 title  similarity  \
# 0           0  39-5094.00  Skincare Specialists    0.552224
# 1           0  39-5094.00  Skincare Specialists    0.552224
# 2           0  39-5094.00  Skincare Specialists    0.552224
# 3           0  39-5094.00  Skincare Specialists    0.552224
# 4           0  39-5094.00  Skincare Specialists    0.552224
#
#                                          description human_judgement notes
# 0  Developing insulin formulations for intraperit...
# 1  Holmdel Imaging is a state of the art diagnost...
# 2  Paragon 28 was established in 2010 as an ortho...
# 3  As a father-daughter duo, Novice Group Dermato...
# 4  In 1978, Brink Chiropractic Clinic was founded...

# %%
cluster_sizes = (
    jobs_labeled.groupby("cluster_id")
    .size()
    .reset_index(name="cluster_size")
)

cluster_summary = cluster_sizes.merge(
    top1_soc[["cluster_id","soc_code","title","similarity"]],
    on="cluster_id",
    how="left"
).sort_values("cluster_size", ascending=False)

cluster_summary.to_csv(PROJECT_ROOT/"results/reports/cluster_summary.csv", index=False)
cluster_summary.head()
# Out:
#     cluster_id  cluster_size    soc_code  \
# 98          98           477  15-1299.09
# 84          84           440  13-1161.00
# 4            4           434  11-9141.00
# 88          88           429  47-2073.00
# 87          87           423  13-1161.00
#
#                                                 title  similarity
# 98            Information Technology Project Managers    0.479991
# 84  Market Research Analysts and Marketing Special...    0.475983
# 4   Property, Real Estate, and Community Associati...    0.640741
# 88  Operating Engineers and Other Construction Equ...    0.525926
# 87  Market Research Analysts and Marketing Special...    0.509092

# %%
low_sim = cluster_summary.sort_values("similarity").head(15)
low_sim.to_csv(PROJECT_ROOT/"results/reports/cluster_low_similarity_watchlist.csv", index=False)
low_sim
# Out:
#     cluster_id  cluster_size    soc_code  \
# 66          66           249  11-9041.00
# 71          71           258  41-4011.00
# 43          43           362  41-3091.00
# 91          91           336  13-1199.00
# 22          22           226  33-3021.06
# 73          73           311  15-1243.01
# 95          95           240  35-9031.00
# 16          16           319  15-1221.00
# 77          77           227  19-3051.00
# 82          82           174  35-3011.00
# 49          49           221  13-1022.00
# 75          75           414  21-1012.00
# 78          78            55  29-2099.08
# 28          28           311  13-1082.00
# 21          21           346  15-1299.08
#
#                                                 title  similarity
# 66             Architectural and Engineering Managers    0.402757
# 71  Sales Representatives, Wholesale and Manufactu...    0.406935
# 43  Sales Representatives of Services, Except Adve...    0.423497
# 91         Business Operations Specialists, All Other    0.426668
# 22                              Intelligence Analysts    0.430240
# 73                       Data Warehousing Specialists    0.431172
# 95  Hosts and Hostesses, Restaurant, Lounge, and C...    0.435082
# 16       Computer and Information Research Scientists    0.437538
# 77                        Urban and Regional Planners    0.450128
# 82                                         Bartenders    0.450866
# 49  Wholesale and Retail Buyers, Except Farm Products    0.454463
# 75  Educational, Guidance, and Career Counselors a...    0.455783
# 78                            Patient Representatives    0.456885
# 28                     Project Management Specialists    0.459419
# 21              Computer Systems Engineers/Architects    0.463634
